# %% [markdown]
# # Descriptive, Inferential, and Exploratory Statistical Analysis
# ## Genomics Sequence Classification Dataset

# %%
# Import and run the analysis script
exec(open('../../scripts/python/descriptive_inferential_exploratory.py').read())
