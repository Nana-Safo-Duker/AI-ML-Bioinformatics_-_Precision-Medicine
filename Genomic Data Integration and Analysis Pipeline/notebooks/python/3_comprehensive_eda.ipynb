# %% [markdown]
# # Comprehensive Exploratory Data Analysis (EDA)
# ## Genomics Sequence Classification Dataset

# %%
# Run comprehensive EDA
exec(open('../../scripts/python/comprehensive_eda.py').read())
