# %% [markdown]
# # Machine Learning Analysis
# ## Genomics Sequence Classification Dataset
#
# This notebook implements multiple ML algorithms for genomics sequence classification.

# %%
# Run ML analysis
exec(open('../../scripts/python/ml_analysis.py').read())
